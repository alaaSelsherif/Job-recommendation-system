# %%
from flask import Flask,  jsonify,request
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.stem import PorterStemmer
from nltk.tokenize import sent_tokenize, word_tokenize
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel 
from sklearn.metrics import mean_squared_error
from math import sqrt
import pandas as pd
import string

# %%
original_data_loaded = pd.read_csv('jobs_skills.csv') #original data loaded
original_data_loaded.columns = ['id','title', 'jobFunction', 'industry', 'skills'] # cloumns we have

enhanced_data=pd.read_csv('jobs_skills.csv') #enhanced data will be saved here
enhanced_data.columns = ['id','title', 'jobFunction', 'industry', 'skills'] # cloumns we have

enhanced_data.sample(10)# discover data we have
# Out:
#                              id                                        title  \
# 64976  5da165a0e43fd1a7ab67b604     Biotechnology Executive - Fresh Graduate
# 70314  5da1700ae43fd1a7ab67cadc               Call Center Agent - Collection
# 44230  5da13ddae43fd1a7ab6764f8                  Customer Support Specialist
# 561    5da0eea4e43fd1a7ab66ba63                   Electromechanical Engineer
# 38503  5da13320e43fd1a7ab674e9b                           Quotation Engineer
# 32061  5da12726e43fd1a7ab67356f  Senior General Ledger Accountant - Hurghada
# 1535   5da0f04fe43fd1a7ab66be32                   Senior Planning Specialist
# 18747  5da10ec2e43fd1a7ab67016d                             Warehouse Keeper
# 38144  5da13273e43fd1a7ab674d32            Architect - Working Drawing + BIM
# 67423  5da16a62e43fd1a7ab67bf90                 Real Estate Sales Specialist
#
#                                              jobFunction  \
# 64976       ['Marketing/PR/Advertising', 'Sales/Retail']
# 70314                       ['Customer Service/Support']
# 44230  ['Customer Service/Support', 'Logistics/Supply...
# 561              ['Engineering - Mechanical/Electrical']
# 38503            ['Engineering - Mechanical/Electrical']
# 32061                             ['Accounting/Finance']
# 1535   ['Engineering - Construction/Civil/Architectur...
# 18747                         ['Logistics/Supply Chain']
# 38144  ['Engineering - Construction/Civil/Architecture']
# 67423       ['Customer Service/Support', 'Sales/Retail']
#
#                                                 industry  \
# 64976                ['Healthcare and Medical Services']
# 70314                ['Healthcare and Medical Services']
# 44230                                  ['Manufacturing']
# 561                  ['Real Estate/Property Management']
# 38503  ['Manufacturing', 'Energy and Utilities', 'Eng...
# 32061                ['Real Estate/Property Management']
# 1535   ['Construction - Residential & Commercial/Offi...
# 18747                                  ['Manufacturing']
# 38144  ['Consulting Services', 'Engineering Services'...
# 67423                ['Real Estate/Property Management']
#
#                                                   skills
# 64976  ['Medical', 'Sales', 'Sales Target', 'Biotechn...
# 70314  ['Accounting', 'Finance', 'Startup', 'Collecti...
# 44230  ['Customer Support', 'Logistics', 'Sales', 'Cu...
# 561    ['Electrical Engineering', 'Design', 'Mechanic...
# 38503  ['Quotation Engineering', 'Electrical Engineer...
# 32061  ['Auditing', 'ACCA', 'Accounting', 'Business A...
# 1535   ['Planning Engineering', 'Planning', 'Civil En...
# 18747  ['Logistics', 'Microsoft Word', 'Warehousing',...
# 38144  ['NFPA', 'Tendering', 'REVIT', 'ADA', 'Civil E...
# 67423  ['Customer Support', 'Sales', 'Property', 'Rea...

# %%
#removing special characters
enhanced_data['title']=enhanced_data['title'].str.encode('ascii', 'ignore').str.decode('ascii')
enhanced_data['jobFunction']=enhanced_data['jobFunction'].str.encode('ascii', 'ignore').str.decode('ascii')
enhanced_data['industry']=enhanced_data['industry'].str.encode('ascii', 'ignore').str.decode('ascii')
enhanced_data['skills']=enhanced_data['skills'].str.encode('ascii', 'ignore').str.decode('ascii')
enhanced_data.sample(5)
# Out:
#                              id                          title  \
# 54327  5da15122e43fd1a7ab678c68  Mathematics Content Developer
# 78622  5da17fcde43fd1a7ab67eb4f                     Accountant
# 39863  5da135ace43fd1a7ab6753e9                Sales Executive
# 82497  5da18717e43fd1a7ab67fa73       Customer Service Manager
# 9025   5da0fd22e43fd1a7ab66db73                Admin Assistant
#
#                                        jobFunction  \
# 54327  ['Writing/Editorial', 'Education/Teaching']
# 78622                       ['Accounting/Finance']
# 39863                             ['Sales/Retail']
# 82497                 ['Customer Service/Support']
# 9025                            ['Administration']
#
#                                                 industry  \
# 54327                        ['Education', 'E-Learning']
# 78622  ['Accounting and Auditing Services', 'Manufact...
# 39863                ['Real Estate/Property Management']
# 82497                ['Real Estate/Property Management']
# 9025                 ['Information Technology Services']
#
#                                                   skills
# 54327  ['Mathematics', 'Educational Content', 'Design...
# 78622  ['IFRS', 'Accounting', 'Financial Analysis', '...
# 39863  ['Marketing Plans', 'Sales', 'Sales Target', '...
# 82497  ['Customer Support', 'Customer Service', 'Comp...
# 9025   ['Business Administration', 'Administration', ...

# %%
#tokenization will done here too
#lower case all letters
enhanced_data['title'] = enhanced_data['title'].str.lower().str.replace(r'[^\w\s]+', ' ').str.split()
#enhanced_data['jobFunction'] = enhanced_data['jobFunction'].str.lower().str.replace(r'[^\w\s]+', ' ').str.split()
#enhanced_data['industry'] = enhanced_data['industry'].str.lower().str.replace(r'[^\w\s]+', ' ').str.split()
enhanced_data['skills'] = enhanced_data['skills'].str.lower().str.replace(r'[^\w\s]+', ' ').str.split()
enhanced_data
# Out:
#                              id  \
# 0      5da0edb0e43fd1a7ab66b833
# 1      5da0edb0e43fd1a7ab66b834
# 2      5da0edb1e43fd1a7ab66b835
# 3      5da0edafe43fd1a7ab66b831
# 4      5da0edaee43fd1a7ab66b82f
# ...                         ...
# 99995  5da1a8f7e43fd1a7ab683ecd
# 99996  5da1a8f8e43fd1a7ab683ece
# 99997  5da1a8f9e43fd1a7ab683ed1
# 99998  5da1a8fae43fd1a7ab683ed2
# 99999  5da1a8f9e43fd1a7ab683ed0
#
#                                                    title  \
# 0                                 [property, consultant]
# 1                  [sales, representative, real, estate]
# 2                                         [receptionist]
# 3                         [senior, property, consultant]
# 4                              [senior, seo, specialist]
# ...                                                  ...
# 99995  [applications, unlimited, sales, representativ...
# 99996  [senior, netsuite, solution, engineer, with, a...
# 99997                [sales, representative, alexandria]
# 99998  [english, instructor, 6th, of, october, part, ...
# 99999                     [sales, representative, cairo]
#
#                                              jobFunction  \
# 0                                       ['Sales/Retail']
# 1           ['Customer Service/Support', 'Sales/Retail']
# 2                                     ['Administration']
# 3                                       ['Sales/Retail']
# 4      ['Marketing/PR/Advertising', 'Media/Journalism...
# ...                                                  ...
# 99995        ['IT/Software Development', 'Sales/Retail']
# 99996  ['IT/Software Development', 'Engineering - Tel...
# 99997                                   ['Sales/Retail']
# 99998      ['Training/Instructor', 'Education/Teaching']
# 99999                                   ['Sales/Retail']
#
#                                                 industry  \
# 0                    ['Real Estate/Property Management']
# 1                    ['Real Estate/Property Management']
# 2                    ['Real Estate/Property Management']
# 3                    ['Real Estate/Property Management']
# 4      ['Real Estate/Property Management', 'Marketing...
# ...                                                  ...
# 99995  ['Information Technology Services', 'Computer ...
# 99996  ['Information Technology Services', 'Computer ...
# 99997  ['Education', 'Business Services - Other', 'Tr...
# 99998                                      ['Education']
# 99999  ['Education', 'Business Services - Other', 'Tr...
#
#                                                   skills
# 0      [sales, retail, real, estate, sales, target, i...
# 1      [sales, real, estate, sales, target, customer,...
# 2      [admin, work, office, management, administrati...
# 3      [sales, real, estate, sales, target, computer,...
# 4      [marketing, campaigns, e, marketing, digital, ...
# ...                                                  ...
# 99995  [peoplesoft, sales, computer, science, outdoor...
# 99996  [computer, science, saas, erp, telecommunicati...
# 99997  [customer, service, customer, care, sales, ski...
# 99998  [translation, linguistics, iqp, education, tra...
# 99999  [customer, service, customer, care, sales, ski...
#
# [100000 rows x 5 columns]

# %%
lis=list()
lis= "['sales', 'retail', 'real', 'estate', 'sales', 'target', 'indoor', 'sales', 'sales', 'skills', 'property', 'sales']"
print(lis)

print(enhanced_data['skills'][0])

if (enhanced_data['skills'][0] == lis):
    print('yes')
else:
    print('no')
# Out:
# ['sales', 'retail', 'real', 'estate', 'sales', 'target', 'indoor', 'sales', 'sales', 'skills', 'property', 'sales']
# ['sales', 'retail', 'real', 'estate', 'sales', 'target', 'indoor', 'sales', 'sales', 'skills', 'property', 'sales']
# no

# %%
data= pd.read_csv("job_skills.csv")
data
# Out:
#        Unnamed: 0                        id  \
# 0               0  5da0edb0e43fd1a7ab66b833
# 1               1  5da0edb0e43fd1a7ab66b834
# 2               2  5da0edb1e43fd1a7ab66b835
# 3               3  5da0edafe43fd1a7ab66b831
# 4               4  5da0edaee43fd1a7ab66b82f
# ...           ...                       ...
# 99995       99995  5da1a8f7e43fd1a7ab683ecd
# 99996       99996  5da1a8f8e43fd1a7ab683ece
# 99997       99997  5da1a8f9e43fd1a7ab683ed1
# 99998       99998  5da1a8fae43fd1a7ab683ed2
# 99999       99999  5da1a8f9e43fd1a7ab683ed0
#
#                                                    title  \
# 0                             ['property', 'consultant']
# 1          ['sales', 'representative', 'real', 'estate']
# 2                                       ['receptionist']
# 3                   ['senior', 'property', 'consultant']
# 4                        ['senior', 'seo', 'specialist']
# ...                                                  ...
# 99995  ['applications', 'unlimited', 'sales', 'repres...
# 99996  ['senior', 'netsuite', 'solution', 'engineer',...
# 99997          ['sales', 'representative', 'alexandria']
# 99998  ['english', 'instructor', '6th', 'of', 'octobe...
# 99999               ['sales', 'representative', 'cairo']
#
#                                              jobFunction  \
# 0                                       ['Sales/Retail']
# 1           ['Customer Service/Support', 'Sales/Retail']
# 2                                     ['Administration']
# 3                                       ['Sales/Retail']
# 4      ['Marketing/PR/Advertising', 'Media/Journalism...
# ...                                                  ...
# 99995        ['IT/Software Development', 'Sales/Retail']
# 99996  ['IT/Software Development', 'Engineering - Tel...
# 99997                                   ['Sales/Retail']
# 99998      ['Training/Instructor', 'Education/Teaching']
# 99999                                   ['Sales/Retail']
#
#                                                 industry  \
# 0                    ['Real Estate/Property Management']
# 1                    ['Real Estate/Property Management']
# 2                    ['Real Estate/Property Management']
# 3                    ['Real Estate/Property Management']
# 4      ['Real Estate/Property Management', 'Marketing...
# ...                                                  ...
# 99995  ['Information Technology Services', 'Computer ...
# 99996  ['Information Technology Services', 'Computer ...
# 99997  ['Education', 'Business Services - Other', 'Tr...
# 99998                                      ['Education']
# 99999  ['Education', 'Business Services - Other', 'Tr...
#
#                                                   skills
# 0      ['sales', 'retail', 'real', 'estate', 'sales',...
# 1      ['sales', 'real', 'estate', 'sales', 'target',...
# 2      ['admin', 'work', 'office', 'management', 'adm...
# 3      ['sales', 'real', 'estate', 'sales', 'target',...
# 4      ['marketing', 'campaigns', 'e', 'marketing', '...
# ...                                                  ...
# 99995  ['peoplesoft', 'sales', 'computer', 'science',...
# 99996  ['computer', 'science', 'saas', 'erp', 'teleco...
# 99997  ['customer', 'service', 'customer', 'care', 's...
# 99998  ['translation', 'linguistics', 'iqp', 'educati...
# 99999  ['customer', 'service', 'customer', 'care', 's...
#
# [100000 rows x 6 columns]

# %%
data['skills'][15]
# Out:
# "['analysis', 'business', 'administration', 'reporting', 'packages', 'data', 'collection', 'business', 'analysis']"

# %%
data['skills'][5]
# Out:
# "['customer', 'support', 'sales', 'property', 'real', 'estate', 'customer', 'service', 'customer', 'care']"

# %% [markdown]
# # Doc2Vec

# %%
# Create the tagged document needed for Doc2Vec
import gensim
from gensim.models import Word2Vec
def create_tagged_document(list_of_list_of_words):
    for i, list_of_words in enumerate(list_of_list_of_words):
        yield gensim.models.doc2vec.TaggedDocument(list_of_words, [i])

train_data = list(create_tagged_document(enhanced_data['skills']))

print(train_data[2156])
#> [TaggedDocument(words=['anarchism', 'originated', ... 'social', 'or', 'emotional'], tags=[0])]
# Out:
# TaggedDocument(['medical', 'veterinary', 'calves', 'veterinary', 'medical'], [2156])

# %%
# Init the Doc2Vec model
model = gensim.models.doc2vec.Doc2Vec(vector_size=60, min_count=0, epochs=10)

# Build the Volabulary
model.build_vocab(train_data)

# Train the Doc2Vec model
model.train(train_data, total_examples=model.corpus_count, epochs=model.epochs)

# %%
print(model.infer_vector(['Sales', 'Real Estate', 'Sales Target']))
# Out:
# [-2.0712570e-03  2.4500662e-03  3.2033210e-03  5.7607316e-03
#   4.2410325e-03 -8.8395190e-04 -3.0653812e-03 -7.8364508e-03
#  -2.6085405e-03 -7.0888799e-04 -3.4298692e-03 -9.6072030e-04
#   3.1590736e-03  5.4945964e-03 -7.3045488e-03 -8.1713693e-03
#  -7.7010258e-03 -5.5852588e-03  4.8673004e-03  2.4651806e-03
#   8.7771466e-04  3.6154406e-03  6.5855281e-03  4.5196693e-03
#  -6.0599054e-05  6.3070650e-03 -7.7849901e-03 -7.7988505e-03
#  -1.0094794e-03 -1.0779860e-03  1.2444756e-03  6.7080455e-03
#   7.3749870e-03  3.8634592e-03 -5.7165180e-03  2.6038187e-03
#  -7.3319660e-03  4.6930085e-03  5.6940871e-03 -7.7121858e-03
#  -4.7379034e-03 -2.5826681e-04  8.2526216e-03  7.2660861e-03
#  -6.3481233e-03  6.5678176e-03 -7.5653628e-03  4.6532722e-03
#   5.7943785e-03  3.9861002e-03  5.6279949e-03 -3.8594827e-03
#  -4.3370519e-03  6.2152254e-03 -3.8127892e-03  3.9333063e-03
#  -4.4246987e-03  2.6482590e-03 -4.6684360e-03 -1.0147508e-03]

# %%
from gensim.matutils import softcossim
from gensim import corpora

# %%
model.n_similarity(['analysis', 'business', 'administration', 'reporting', 'packages', 'data', 'collection', 'business', 'analysis'],['sales', 'veterinary', 'calves', 'veterinary', 'medical'])
# Out:
# C:\Users\Alaa Elsherif\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `n_similarity` (Method will be removed in 4.0.0, use self.wv.n_similarity() instead).
#   """Entry point for launching an IPython kernel.
# 0.4709833

# %%
#function get name of job 
def job(skill = [], *args):
    for idx in enhanced_data.index:
        if skill==enhanced_data['skills'][idx]:
            print(enhanced_data['title'][idx])
            break
            
job(['administration', 'biling'])
# Out:
# ['billing', 'specialist']

# %% [markdown]
# # recommendation using n_similarity

# %%
def recommended(skill = [] ,*args):
    li=list()
    for idx in enhanced_data.index:
        sim=model.n_similarity(skill,enhanced_data['skills'][idx])
        #title=job(enhanced_data['skills'][idx])
        if sim>0.97:
            print("Recommended jobs: ")
            print(job(enhanced_data['skills'][idx]))
            print(sim)
            
        
    
    #for i in  li:
      #  print(li[i])

# %%
recommended(['training', 'real', 'estate', 'sales'])
# Out:
# C:\Users\Alaa Elsherif\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: DeprecationWarning: Call to deprecated `n_similarity` (Method will be removed in 4.0.0, use self.wv.n_similarity() instead).
#   after removing the cwd from sys.path.
# Recommended jobs:
# ['sales', 'trainer']
# None
# 1.0
# Recommended jobs:
# ['sales', 'trainer']
# None
# 1.0
# Recommended jobs:
# ['sales', 'trainer']
# None
# 1.0
# Recommended jobs:
# ['sales', 'trainer']
# None
# 1.0
# Recommended jobs:
# ['sales', 'trainer']
# None
# 1.0
# Recommended jobs:
# ['sales', 'trainer']
# None
# 1.0
# Recommended jobs:
# ['sales', 'trainer']
# None
# 1.0
# Recommended jobs:
# ['sales', 'trainer']
# None
# 1.0
# Recommended jobs:
# ['sales', 'trainer']
# None
# 1.0
# Recommended jobs:
# ['sales', 'trainer']
# None
# 1.0
# Recommended jobs:
# ['sales', 'trainer']
# None
# 1.0
# Recommended jobs:
# ['sales', 'trainer']
# None
# 1.0
# Recommended jobs:
# ['sales', 'trainer']
# None
# 1.0
# Recommended jobs:
# ['sales', 'trainer']
# None
# 1.0
# Recommended jobs:
# ['sales', 'trainer']
# None
# 1.0
# Recommended jobs:
# ['sales', 'trainer']
# None
# 1.0
# Recommended jobs:
# ['sales', 'trainer']
# None
# 1.0
# Recommended jobs:
# ['sales', 'trainer']
# None
# 1.0

# %%
#  gap analysis results
def gap_analysis(skill = [] ,*args):
    li=list()
    for idx in enhanced_data.index:
        sim=model.wv.n_similarity(skill,enhanced_data['skills'][idx])
        #result=model.infer_vector(skill) - model.infer_vector(enhanced_data['skills'][idx])
        gap=list(set(skill).symmetric_difference(enhanced_data['skills'][idx]))
        #title=job(enhanced_data['skills'][idx])
        if sim > 0.93:
            print("Recommended job and gap analysis: ")
            print(job(enhanced_data['skills'][idx]))
            print(gap)

# %%
gap_analysis(['training', 'real', 'estate', 'sales'])
# Out:
# Recommended job and gap analysis:
# ['sales', 'trainer']
# None
# []
# Recommended job and gap analysis:
# ['business', 'development', 'executive', 'real', 'estate']
# None
# ['business', 'development']
# Recommended job and gap analysis:
# ['business', 'development', 'executive', 'real', 'estate']
# None
# ['business', 'development']
# Recommended job and gap analysis:
# ['sales', 'trainer']
# None
# []
# Recommended job and gap analysis:
# ['business', 'development', 'executive', 'real', 'estate']
# None
# ['business', 'development']
# Recommended job and gap analysis:
# ['sales', 'trainer']
# None
# []
# Recommended job and gap analysis:
# ['business', 'development', 'executive', 'real', 'estate']
# None
# ['business', 'development']
# Recommended job and gap analysis:
# ['sales', 'trainer']
# None
# []
# Recommended job and gap analysis:
# ['sales', 'trainer']
# None
# []
# Recommended job and gap analysis:
# ['business', 'development', 'executive', 'real', 'estate']
# None
# ['business', 'development']
# Recommended job and gap analysis:
# ['sales', 'trainer']
# None
# []
# Recommended job and gap analysis:
# ['business', 'development', 'executive', 'real', 'estate']
# None
# ['business', 'development']
# Recommended job and gap analysis:
# ['sales', 'trainer']
# None
# []
# Recommended job and gap analysis:
# ['business', 'development', 'executive', 'real', 'estate']
# None
# ['business', 'development']
# Recommended job and gap analysis:
# ['sales', 'trainer']
# None
# []
# Recommended job and gap analysis:
# ['sales', 'trainer']
# None
# []
# Recommended job and gap analysis:
# ['business', 'development', 'executive', 'real', 'estate']
# None
# ['business', 'development']
# Recommended job and gap analysis:
# ['business', 'development', 'executive', 'real', 'estate']
# None
# ['business', 'development']
# Recommended job and gap analysis:
# ['sales', 'trainer']
# None
# []
# Recommended job and gap analysis:
# ['business', 'development', 'executive', 'real', 'estate']
# None
# ['business', 'development']
# Recommended job and gap analysis:
# ['sales', 'trainer']
# None
# []
# Recommended job and gap analysis:
# ['business', 'development', 'executive', 'real', 'estate']
# None
# ['business', 'development']
# Recommended job and gap analysis:
# ['sales', 'trainer']
# None
# []
# Recommended job and gap analysis:
# ['business', 'development', 'executive', 'real', 'estate']
# None
# ['business', 'development']
# Recommended job and gap analysis:
# ['business', 'development', 'executive', 'real', 'estate']
# None
# ['business', 'development']
# Recommended job and gap analysis:
# ['sales', 'trainer']
# None
# []
# Recommended job and gap analysis:
# ['sales', 'trainer']
# None
# []
# Recommended job and gap analysis:
# ['business', 'development', 'executive', 'real', 'estate']
# None
# ['business', 'development']
# Recommended job and gap analysis:
# ['sales', 'trainer']
# None
# []
# Recommended job and gap analysis:
# ['business', 'development', 'executive', 'real', 'estate']
# None
# ['business', 'development']
# Recommended job and gap analysis:
# ['business', 'development', 'executive', 'real', 'estate']
# None
# ['business', 'development']
# Recommended job and gap analysis:
# ['business', 'development', 'executive', 'real', 'estate']
# None
# ['business', 'development']
# Recommended job and gap analysis:
# ['sales', 'trainer']
# None
# []
# Recommended job and gap analysis:
# ['sales', 'trainer']
# None
# []
# Recommended job and gap analysis:
# ['business', 'development', 'executive', 'real', 'estate']
# None
# ['business', 'development']
# Recommended job and gap analysis:
# ['sales', 'trainer']
# None
# []
# Recommended job and gap analysis:
# ['business', 'development', 'executive', 'real', 'estate']
# None
# ['business', 'development']
